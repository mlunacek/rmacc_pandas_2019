# %% [markdown]
# # Concat

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(12,6)})
plt.style.use(['seaborn-whitegrid'])

import warnings
warnings.simplefilter('ignore')

import os
import utils

# %% [markdown]
# Our `read_csv` function.

# %% [markdown]
# ```python
#     import pandas as pd
#
#     def read_csv(filename):
#         df = pd.read_csv(filename, skiprows=8)
#         df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
#         df['timestamp'] = pd.to_datetime(df['timestamp'])  #might not want this here
#         df.set_index('timestamp', inplace=True)
#         return df
# ```

# %%
filenames = ['data/measured_real_power.csv',
             'data/measured_reactive_power.csv']

# %% [markdown]
# Concat

# %%
df1 = utils.read_csv(filenames[0])
df2 = utils.read_csv(filenames[1])

df = pd.concat([df1, df2], axis=1) # stack side by side

# %%
df1.shape, df2.shape, df.shape
# Out:
# ((12961, 20), (12961, 20), (12961, 40))

# %%
len(set(df.columns))
# Out:
# 20

# %%
all(df1.columns == df2.columns)
# Out:
# True

# %% [markdown]
# So now we need to capture some additional information.

# %%
def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df.timestamp = pd.to_datetime(df.timestamp)
    df.set_index('timestamp', inplace=True)
    prefix = os.path.basename(filename).replace('.csv','')
    df.columns = [ "{}:{}".format(prefix, x) for x in df.columns ]
    return df

df = pd.concat([ read_csv(x) for x in filenames ], axis=1)
len(set(df.columns))
# Out:
# 40

# %%
df.columns
# Out:
# Index(['measured_real_power:triplex_meter_0',
#        'measured_real_power:triplex_meter_1',
#        'measured_real_power:triplex_meter_2',
#        'measured_real_power:triplex_meter_3',
#        'measured_real_power:triplex_meter_4',
#        'measured_real_power:triplex_meter_5',
#        'measured_real_power:triplex_meter_6',
#        'measured_real_power:triplex_meter_7',
#        'measured_real_power:triplex_meter_8',
#        'measured_real_power:triplex_meter_9',
#        'measured_real_power:triplex_meter_10',
#        'measured_real_power:triplex_meter_11',
#        'measured_real_power:triplex_meter_12',
#        'measured_real_power:triplex_meter_13',
#        'measured_real_power:triplex_meter_14',
#        'measured_real_power:triplex_meter_15',
#        'measured_real_power:triplex_meter_16',
#        'measured_real_power:triplex_meter_17',
#        'measured_real_power:triplex_meter_18',
#        'measured_real_power:triplex_meter_19',
#        'measured_reactive_power:triplex_meter_0',
#        'measured_reactive_power:triplex_meter_1',
#        'measured_reactive_power:triplex_meter_2',
#        'measured_reactive_power:triplex_meter_3',
#        'measured_reactive_power:triplex_meter_4',
#        'measured_reactive_power:triplex_meter_5',
#        'measured_reactive_power:triplex_meter_6',
#        'measured_reactive_power:triplex_meter_7',
#        'measured_reactive_power:triplex_meter_8',
#        'measured_reactive_power:triplex_meter_9',
#        'measured_reactive_power:triplex_meter_10',
#        'measured_reactive_power:triplex_meter_11',
#        'measured_reactive_power:triplex_meter_12',
#        'measured_reactive_power:triplex_meter_13',
#        'measured_reactive_power:triplex_meter_14',
#        'measured_reactive_power:triplex_meter_15',
#        'measured_reactive_power:triplex_meter_16',
#        'measured_reactive_power:triplex_meter_17',
#        'measured_reactive_power:triplex_meter_18',
#        'measured_reactive_power:triplex_meter_19'],
#       dtype='object')

# %% [markdown]
# ## Glob

# %%
import glob

# %%
filenames = glob.glob('data/outputFiles/*.csv')
filenames
# Out:
# ['data/outputFiles/triplex_meter:monthly_bill.csv',
#  'data/outputFiles/triplex_meter:measured_real_power.csv',
#  'data/outputFiles/house:outdoor_temperature.csv',
#  'data/outputFiles/house:heating_setpoint.csv',
#  'data/outputFiles/house:hvac_power.imag.csv',
#  'data/outputFiles/house:incident_solar_radiation.csv',
#  'data/outputFiles/house:air_temperature.csv',
#  'data/outputFiles/house:mass_temperature.csv',
#  'data/outputFiles/house:cooling_setpoint.csv',
#  'data/outputFiles/triplex_meter:measured_reactive_power.csv',
#  'data/outputFiles/house:hvac_power.real.csv',
#  'data/outputFiles/triplex_meter:price.csv',
#  'data/outputFiles/triplex_meter:monthly_energy.csv']

# %%
def read_dir(filenames):
    return pd.concat([ read_csv(x) for x in filenames ], axis=1)

read_dir(filenames).shape
# Out:
# (12961, 260)

# %% [markdown]
# Takes a while... Can we do better?

# %%
import cProfile

cProfile.run('read_dir(filenames)')
# Out:
#          118750698 function calls (118748645 primitive calls) in 64.428 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       384    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:103(release)
#       384    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       384    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       384    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       384    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       384    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:176(cb)
#   264/120    0.000    0.000    0.023    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#      1800    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#       120    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       337    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#       384    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:58(__init__)
#       120    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:707(find_spec)
#       384    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:78(acquire)
#       120    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:780(find_spec)
#       480    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:843(__enter__)
#       480    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:847(__exit__)
#       120    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#       120    0.001    0.000    0.018    0.000 <frozen importlib._bootstrap>:870(_find_spec)
#   384/120    0.001    0.000    0.024    0.000 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#   384/120    0.002    0.000    0.026    0.000 <frozen importlib._bootstrap>:966(_find_and_load)
#      1992    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#       408    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#       120    0.001    0.000    0.016    0.000 <frozen importlib._bootstrap_external>:1117(_get_spec)
#       120    0.000    0.000    0.016    0.000 <frozen importlib._bootstrap_external>:1149(find_spec)
#       360    0.003    0.000    0.012    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1310(<setcomp>)
#       360    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:37(_relax_case)
#      1800    0.001    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#      1800    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#       360    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#         1    0.001    0.001   64.426   64.426 <ipython-input-14-87837378269a>:1(read_dir)
#         1    0.000    0.000   64.384   64.384 <ipython-input-14-87837378269a>:2(<listcomp>)
#        24    0.005    0.000   64.384    2.683 <ipython-input-7-81cda3ebd4a7>:1(read_csv)
#        24    0.000    0.000    0.000    0.000 <ipython-input-7-81cda3ebd4a7>:7(<listcomp>)
#         1    0.002    0.002   64.428   64.428 <string>:1(<module>)
#        72    0.000    0.000    0.000    0.000 <string>:12(__new__)
#        24    0.000    0.000    0.000    0.000 __init__.py:125(lrange)
#       313    0.000    0.000    0.000    0.000 __init__.py:221(iteritems)
#        24    0.000    0.000    0.000    0.000 __init__.py:227(itervalues)
#       363    0.000    0.000    0.000    0.000 __init__.py:246(__str__)
#        24    0.000    0.000    0.000    0.000 __init__.py:425(FixedOffset)
#        24    0.000    0.000    0.000    0.000 __init__.py:457(is_platform_windows)
#        24    0.000    0.000    0.030    0.001 _decorators.py:195(wrapper)
#       892    0.002    0.000    0.006    0.000 _dtype.py:319(_name_get)
#       190    0.000    0.000    0.002    0.000 _dtype.py:46(__str__)
#    311053    0.129    0.000    0.129    0.000 _factories.py:11(__call__)
#       265    0.000    0.000    0.000    0.000 _internal.py:886(npy_ctypes_check)
#       168    0.000    0.000    0.001    0.000 _methods.py:42(_any)
#        37    0.000    0.000    0.000    0.000 _methods.py:45(_all)
#    622106    0.859    0.000    1.682    0.000 _parser.py:1009(_find_hms_idx)
#    933159    0.885    0.000    1.814    0.000 _parser.py:1059(_could_be_tzname)
#   1866318    0.518    0.000    0.518    0.000 _parser.py:1064(<genexpr>)
#    311053    0.278    0.000    0.278    0.000 _parser.py:1102(_parse_min_sec)
#    311053    0.174    0.000    0.174    0.000 _parser.py:1114(_parsems)
#    311053    0.566    0.000    1.337    0.000 _parser.py:1171(_build_tzaware)
#    311053    0.851    0.000    1.847    0.000 _parser.py:1211(_build_naive)
#    933159    0.658    0.000    0.761    0.000 _parser.py:1244(_to_decimal)
#    311053    0.498    0.000   48.466    0.000 _parser.py:1260(parse)
#    311053    0.044    0.000    0.044    0.000 _parser.py:192(__iter__)
#   4354742    1.409    0.000   16.666    0.000 _parser.py:195(__next__)
#    311053    1.427    0.000   19.201    0.000 _parser.py:205(split)
#   4665795    0.994    0.000    1.433    0.000 _parser.py:209(isword)
#   8087378    1.633    0.000    2.301    0.000 _parser.py:214(isnum)
#   1866318    0.398    0.000    0.580    0.000 _parser.py:219(isspace)
#    311053    0.654    0.000    1.208    0.000 _parser.py:227(__init__)
#    311053    0.256    0.000    2.376    0.000 _parser.py:239(__len__)
#   4043689    0.979    0.000    1.504    0.000 _parser.py:240(<genexpr>)
#    933159    0.382    0.000    0.483    0.000 _parser.py:325(jump)
#    933159    0.532    0.000    0.638    0.000 _parser.py:328(weekday)
#   1244212    0.700    0.000    0.828    0.000 _parser.py:335(month)
#    933159    0.659    0.000    0.768    0.000 _parser.py:342(hms)
#    933159    0.495    0.000    0.581    0.000 _parser.py:348(ampm)
#    311053    0.137    0.000    0.175    0.000 _parser.py:357(utczone)
#    311053    0.180    0.000    0.242    0.000 _parser.py:360(tzoffset)
#    311053    0.080    0.000    0.080    0.000 _parser.py:366(convertyear)
#    311053    0.471    0.000    0.726    0.000 _parser.py:386(validate)
#    311053    0.439    0.000    0.439    0.000 _parser.py:401(__init__)
#    311053    0.074    0.000    0.074    0.000 _parser.py:408(has_year)
#    933159    1.839    0.000    2.458    0.000 _parser.py:434(append)
#    311053    1.075    0.000    1.437    0.000 _parser.py:480(resolve_ymd)
#    311053    0.209    0.000    0.209    0.000 _parser.py:488(<dictcomp>)
#    311053    0.944    0.000   47.969    0.000 _parser.py:578(parse)
#    311053    0.722    0.000    1.063    0.000 _parser.py:62(__init__)
#    311053    5.002    0.000   41.211    0.000 _parser.py:669(_parse)
#   4354742    9.056    0.000   15.258    0.000 _parser.py:83(get_token)
#    622106    2.922    0.000    8.956    0.000 _parser.py:878(_parse_numeric_token)
#   1244212    0.567    0.000    3.544    0.000 _strptime.py:29(_getlang)
#   1244212    4.946    0.000   10.118    0.000 _strptime.py:321(_strptime)
#   1244212    0.478    0.000   10.596    0.000 _strptime.py:562(_strptime_datetime)
#        48    0.000    0.000    0.000    0.000 _validators.py:221(validate_bool_kwarg)
#        24    0.000    0.000    0.000    0.000 _validators.py:230(validate_axis_style_args)
#      1471    0.001    0.000    0.001    0.000 _weakrefset.py:70(__contains__)
#      1015    0.001    0.000    0.002    0.000 abc.py:180(__instancecheck__)
#        52    0.000    0.000    0.002    0.000 algorithms.py:1417(_get_take_nd_function)
#        52    0.001    0.000    0.006    0.000 algorithms.py:1544(take_nd)
#         1    0.000    0.000    0.005    0.005 api.py:128(_union_indexes)
#         1    0.000    0.000    0.000    0.000 api.py:205(_sanitize_and_check)
#         1    0.000    0.000    0.000    0.000 api.py:226(<setcomp>)
#         1    0.000    0.000    0.005    0.005 api.py:44(_get_objs_combined_axis)
#         1    0.000    0.000    0.000    0.000 api.py:67(<listcomp>)
#         1    0.000    0.000    0.000    0.000 api.py:73(_get_distinct_objs)
#         1    0.000    0.000    0.005    0.005 api.py:87(_get_combined_index)
#       405    0.000    0.000    0.002    0.000 arrays.py:7(extract_array)
#        24    0.000    0.000    0.000    0.000 base.py:100(_reset_cache)
#        72    0.000    0.000    0.002    0.000 base.py:1117(__iter__)
#        72    0.000    0.000    0.000    0.000 base.py:1396(nlevels)
#        22    0.000    0.000    0.001    0.000 base.py:1580(is_monotonic)
#        22    0.001    0.000    0.001    0.000 base.py:1587(is_monotonic_increasing)
#        35    0.000    0.000    0.000    0.000 base.py:1658(is_unique)
#        11    0.000    0.000    0.000    0.000 base.py:1669(is_boolean)
#        48    0.000    0.000    0.000    0.000 base.py:1681(is_object)
#        48    0.000    0.000    0.000    0.000 base.py:1736(is_all_dates)
#        12    0.000    0.000    0.000    0.000 base.py:2238(_get_reconciled_name_object)
#        23    0.000    0.000    0.000    0.000 base.py:2249(_validate_sort_keyword)
#        23    0.000    0.000    0.004    0.000 base.py:2254(union)
#   241/169    0.004    0.000    0.029    0.000 base.py:253(__new__)
#        23    0.000    0.000    0.000    0.000 base.py:2590(_assert_can_do_setop)
#       144    0.000    0.000    0.000    0.000 base.py:2650(get_loc)
#        11    0.000    0.000    0.010    0.001 base.py:2715(get_indexer)
#        11    0.000    0.000    0.010    0.001 base.py:3089(reindex)
#       192    0.000    0.000    0.000    0.000 base.py:3608(values)
#       240    0.000    0.000    0.000    0.000 base.py:3632(_values)
#        96    0.000    0.000    0.000    0.000 base.py:3663(get_values)
#       144    0.001    0.000    0.001    0.000 base.py:3918(__contains__)
#        24    0.000    0.000    0.000    0.000 base.py:3926(contains)
#       381    0.001    0.000    0.002    0.000 base.py:3940(__getitem__)
#        48    0.000    0.000    0.001    0.000 base.py:3975(_can_hold_identifiers_and_holds_name)
#         1    0.000    0.000    0.001    0.001 base.py:3988(append)
#         1    0.000    0.000    0.000    0.000 base.py:4012(<setcomp>)
#         1    0.000    0.000    0.001    0.001 base.py:4017(_concat)
#         1    0.000    0.000    0.000    0.000 base.py:4025(_concat_same_dtype)
#        48    0.000    0.000    0.002    0.000 base.py:4051(equals)
#        24    0.000    0.000    0.001    0.000 base.py:4071(identical)
#        48    0.000    0.000    0.000    0.000 base.py:4077(<genexpr>)
#        48    0.000    0.000    0.000    0.000 base.py:475(<genexpr>)
#       193    0.001    0.000    0.002    0.000 base.py:504(_simple_new)
#        24    0.000    0.000    0.006    0.000 base.py:5277(ensure_index_from_sequences)
#       480    0.001    0.000    0.035    0.000 base.py:5318(ensure_index)
#        11    0.000    0.000    0.000    0.000 base.py:5381(_ensure_has_len)
#        61    0.000    0.000    0.000    0.000 base.py:547(_get_attributes_dict)
#        61    0.000    0.000    0.000    0.000 base.py:551(<dictcomp>)
#        59    0.000    0.000    0.001    0.000 base.py:566(_shallow_copy)
#         1    0.000    0.000    0.000    0.000 base.py:584(_shallow_copy_with_infer)
#       106    0.000    0.000    0.000    0.000 base.py:613(is_)
#       300    0.000    0.000    0.000    0.000 base.py:633(_reset_identity)
#        24    0.000    0.000    0.000    0.000 base.py:640(_cleanup)
#        58    0.000    0.000    0.000    0.000 base.py:643(_engine)
#        57    0.000    0.000    0.000    0.000 base.py:646(<lambda>)
#       795    0.000    0.000    0.001    0.000 base.py:652(__len__)
#       120    0.000    0.000    0.000    0.000 base.py:676(dtype)
#        48    0.000    0.000    0.001    0.000 base.py:700(view)
#      5464    0.004    0.000    0.026    0.000 base.py:75(is_dtype)
#        24    0.000    0.000    0.000    0.000 base.py:759(size)
#        24    0.000    0.000    0.000    0.000 base.py:963(_ndarray_values)
#        24    0.000    0.000    0.000    0.000 base.py:978(empty)
#        72    0.000    0.000    0.001    0.000 blocks.py:1549(__init__)
#        24    0.000    0.000    0.000    0.000 blocks.py:1577(iget)
#        24    0.000    0.000    0.000    0.000 blocks.py:161(external_values)
#       216    0.000    0.000    0.000    0.000 blocks.py:165(internal_values)
#        72    0.000    0.000    0.001    0.000 blocks.py:1679(__init__)
#        24    0.000    0.000    0.000    0.000 blocks.py:175(get_values)
#        24    0.000    0.000    0.000    0.000 blocks.py:191(fill_value)
#       806    0.000    0.000    0.000    0.000 blocks.py:195(mgr_locs)
#       358    0.001    0.000    0.001    0.000 blocks.py:199(mgr_locs)
#        72    0.000    0.000    0.001    0.000 blocks.py:2094(__init__)
#       144    0.000    0.000    0.000    0.000 blocks.py:2245(_holder)
#       144    0.000    0.000    0.000    0.000 blocks.py:2249(_maybe_coerce_values)
#       120    0.000    0.000    0.002    0.000 blocks.py:225(make_block_same_class)
#        24    0.000    0.000    0.000    0.000 blocks.py:255(__len__)
#        96    0.000    0.000    0.001    0.000 blocks.py:2626(__init__)
#        24    0.000    0.000    0.001    0.000 blocks.py:2736(should_store)
#       512    0.002    0.000    0.015    0.000 blocks.py:3034(get_block_type)
#        96    0.000    0.000    0.000    0.000 blocks.py:304(shape)
#       239    0.000    0.000    0.000    0.000 blocks.py:308(dtype)
#       323    0.001    0.000    0.012    0.000 blocks.py:3080(make_block)
#        59    0.000    0.000    0.000    0.000 blocks.py:3100(_extend_blocks)
#       190    0.000    0.000    0.003    0.000 blocks.py:312(ftype)
#        24    0.000    0.000    0.000    0.000 blocks.py:332(iget)
#        59    0.000    0.000    0.016    0.000 blocks.py:749(copy)
#       323    0.001    0.000    0.003    0.000 blocks.py:78(__init__)
#       323    0.000    0.000    0.000    0.000 blocks.py:89(_check_ndim)
#       144    0.001    0.000    0.001    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#        80    0.000    0.000    0.000    0.000 cast.py:1218(construct_1d_ndarray_preserving_na)
#        52    0.000    0.000    0.001    0.000 cast.py:255(maybe_promote)
#       333    0.001    0.000    0.002    0.000 cast.py:832(maybe_castable)
#        80    0.000    0.000    0.001    0.000 cast.py:846(maybe_infer_to_datetimelike)
#       128    0.001    0.000    0.003    0.000 cast.py:953(maybe_cast_to_datetime)
#       241    0.000    0.000    0.003    0.000 common.py:1078(is_datetime64_any_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:1118(is_datetime64_ns_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:112(_validate_header_arg)
#      2344    0.001    0.000    0.001    0.000 common.py:117(classes)
#      2344    0.001    0.000    0.001    0.000 common.py:119(<lambda>)
#        60    0.000    0.000    0.000    0.000 common.py:1198(is_datetime_or_timedelta_dtype)
#        48    0.000    0.000    0.014    0.000 common.py:120(_stringify_path)
#      1051    0.000    0.000    0.000    0.000 common.py:122(classes_and_not_datetimelike)
#      1051    0.001    0.000    0.001    0.000 common.py:127(<lambda>)
#       805    0.001    0.000    0.002    0.000 common.py:131(is_object_dtype)
#        36    0.000    0.000    0.001    0.000 common.py:1431(needs_i8_conversion)
#       357    0.000    0.000    0.000    0.000 common.py:144(cast_scalar_indexer)
#        24    0.000    0.000    0.000    0.000 common.py:1513(is_string_like_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:1542(<lambda>)
#       565    0.001    0.000    0.001    0.000 common.py:1545(is_float_dtype)
#       241    0.001    0.000    0.002    0.000 common.py:1578(is_bool_dtype)
#       825    0.001    0.000    0.003    0.000 common.py:160(is_sparse)
#         1    0.000    0.000    0.000    0.000 common.py:162(_not_none)
#        24    0.000    0.000    0.000    0.000 common.py:163(is_s3_url)
#        25    0.000    0.000    0.000    0.000 common.py:164(<genexpr>)
#       200    0.000    0.000    0.004    0.000 common.py:1643(is_extension_type)
#      2490    0.003    0.000    0.007    0.000 common.py:1702(is_extension_array_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:171(is_gcs_url)
#        24    0.000    0.000    0.000    0.000 common.py:175(_all_none)
#       156    0.000    0.000    0.001    0.000 common.py:1784(_is_dtype)
#        24    0.000    0.000    0.007    0.000 common.py:179(get_filepath_or_buffer)
#       675    0.001    0.000    0.001    0.000 common.py:1809(_get_dtype)
#      3395    0.003    0.000    0.008    0.000 common.py:1845(_is_dtype_type)
#      1369    0.001    0.000    0.001    0.000 common.py:1981(pandas_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:199(count_not_none)
#        72    0.000    0.000    0.000    0.000 common.py:201(<genexpr>)
#       217    0.001    0.000    0.002    0.000 common.py:222(asarray_tuplesafe)
#        24    0.000    0.000    0.008    0.000 common.py:260(_infer_compression)
#       712    0.000    0.000    0.006    0.000 common.py:262(is_categorical)
#        96    0.000    0.000    0.000    0.000 common.py:316(apply_if_callable)
#       481    0.001    0.000    0.003    0.000 common.py:403(is_datetime64_dtype)
#      1479    0.001    0.000    0.007    0.000 common.py:434(is_datetime64tz_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:457(_get_rename_function)
#       309    0.000    0.000    0.000    0.000 common.py:464(f)
#       433    0.000    0.000    0.002    0.000 common.py:472(is_timedelta64_dtype)
#       917    0.001    0.000    0.006    0.000 common.py:503(is_period_dtype)
#       998    0.001    0.000    0.005    0.000 common.py:536(is_interval_dtype)
#      2552    0.002    0.000    0.014    0.000 common.py:572(is_categorical_dtype)
#       132    0.000    0.000    0.001    0.000 common.py:605(is_string_dtype)
#       132    0.000    0.000    0.001    0.000 common.py:634(condition)
#        72    0.000    0.000    0.001    0.000 common.py:702(is_datetimelike)
#       104    0.000    0.000    0.001    0.000 common.py:746(is_dtype_equal)
#        24    0.000    0.000    0.001    0.000 common.py:76(_is_url)
#        11    0.000    0.000    0.000    0.000 common.py:784(is_dtype_union_equal)
#       761    0.001    0.000    0.002    0.000 common.py:868(is_integer_dtype)
#       145    0.000    0.000    0.000    0.000 common.py:923(is_signed_integer_dtype)
#        24    0.000    0.000    0.000    0.000 common.py:93(is_bool_indexer)
#        72    0.000    0.000    0.000    0.000 common.py:94(_expand_user)
#       145    0.000    0.000    0.000    0.000 common.py:980(is_unsigned_integer_dtype)
#        37    0.000    0.000    0.000    0.000 concat.py:104(__init__)
#        24    0.000    0.000    0.000    0.000 concat.py:117(needs_filling)
#        24    0.000    0.000    0.001    0.000 concat.py:126(dtype)
#        24    0.000    0.000    0.001    0.000 concat.py:137(is_na)
#        24    0.000    0.000    0.004    0.000 concat.py:165(get_reindexed_values)
#         1    0.000    0.000    0.001    0.001 concat.py:20(get_dtype_kinds)
#        24    0.000    0.000    0.000    0.000 concat.py:22(get_mgr_concatenation_plan)
#        24    0.000    0.000    0.007    0.000 concat.py:230(concatenate_join_units)
#         1    0.000    0.000    0.006    0.006 concat.py:237(__init__)
#         1    0.000    0.000    0.041    0.041 concat.py:24(concat)
#        24    0.000    0.000    0.004    0.000 concat.py:240(<listcomp>)
#        24    0.000    0.000    0.002    0.000 concat.py:261(get_empty_dtype_and_na)
#         1    0.000    0.000    0.000    0.000 concat.py:309(<listcomp>)
#        24    0.000    0.000    0.001    0.000 concat.py:367(is_uniform_join_units)
#        48    0.000    0.000    0.000    0.000 concat.py:376(<genexpr>)
#        48    0.000    0.000    0.001    0.000 concat.py:379(<genexpr>)
#        48    0.000    0.000    0.000    0.000 concat.py:381(<genexpr>)
#         1    0.000    0.000    0.034    0.034 concat.py:383(get_result)
#        24    0.000    0.000    0.000    0.000 concat.py:388(is_uniform_reindex)
#        48    0.000    0.000    0.000    0.000 concat.py:391(<genexpr>)
#        38    0.000    0.000    0.000    0.000 concat.py:425(combine_concat_plans)
#         1    0.000    0.000    0.000    0.000 concat.py:434(_get_result_dim)
#         1    0.000    0.000    0.006    0.006 concat.py:440(_get_new_axes)
#         1    0.000    0.000    0.005    0.005 concat.py:464(_get_comb_axis)
#         1    0.000    0.000    0.001    0.001 concat.py:475(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:486(_concat_index_asobject)
#         1    0.000    0.000    0.000    0.000 concat.py:496(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:503(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:507(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:523(_maybe_check_integrity)
#         1    0.000    0.000    0.001    0.001 concat.py:531(_concat_indexes)
#         1    0.000    0.000    0.000    0.000 concat.py:84(_get_frame_result_type)
#         2    0.000    0.000    0.000    0.000 concat.py:92(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:93(<genexpr>)
#         2    0.000    0.000    0.000    0.000 concat.py:97(<genexpr>)
#        24    0.000    0.000    0.082    0.003 construction.py:170(init_dict)
#        24    0.000    0.000    0.014    0.001 construction.py:254(_homogenize)
#        24    0.000    0.000    0.052    0.002 construction.py:43(arrays_to_mgr)
#       405    0.002    0.000    0.017    0.000 construction.py:537(sanitize_array)
#       381    0.000    0.000    0.007    0.000 construction.py:684(_try_cast)
#        66    0.000    0.000    0.000    0.000 datetimelike.py:124(_ndarray_values)
#       116    0.000    0.000    0.000    0.000 datetimelike.py:137(asi8)
#        58    0.000    0.000    0.003    0.000 datetimelike.py:144(equals)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:1502(validate_inferred_freq)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:1537(maybe_infer_freq)
#        11    0.001    0.000    0.001    0.000 datetimelike.py:178(wrapper)
#       188    0.000    0.000    0.000    0.000 datetimelike.py:351(asi8)
#        66    0.000    0.000    0.000    0.000 datetimelike.py:365(_ndarray_values)
#       202    0.000    0.000    0.000    0.000 datetimelike.py:409(__len__)
#        72    0.000    0.000    0.002    0.000 datetimelike.py:607(copy)
#        34    0.000    0.000    0.000    0.000 datetimelike.py:76(freq)
#       226    0.000    0.000    0.000    0.000 datetimelike.py:811(freq)
#        22    0.000    0.000    0.000    0.000 datetimes.py:1199(inferred_type)
#        24    0.000    0.000   63.574    2.649 datetimes.py:134(_convert_listlike_datetimes)
#        24    0.000    0.000    0.002    0.000 datetimes.py:1681(sequence_to_dt64ns)
#        24    0.000    0.000   63.572    2.649 datetimes.py:1815(objects_to_datetime64ns)
#        48    0.000    0.000    0.002    0.000 datetimes.py:1892(maybe_convert_dtype)
#        24    0.000    0.000    0.000    0.000 datetimes.py:1950(maybe_infer_tz)
#        48    0.000    0.000    0.000    0.000 datetimes.py:1979(_validate_dt64_dtype)
#        72    0.000    0.000    0.000    0.000 datetimes.py:2020(validate_tz_from_dtype)
#        24    0.000    0.000    0.004    0.000 datetimes.py:265(__new__)
#        24    0.000    0.000    0.001    0.000 datetimes.py:280(__init__)
#        59    0.000    0.000    0.002    0.000 datetimes.py:309(_simple_new)
#        24    0.000    0.000    0.010    0.000 datetimes.py:31(_maybe_cache)
#       155    0.000    0.000    0.001    0.000 datetimes.py:353(_simple_new)
#       285    0.000    0.000    0.000    0.000 datetimes.py:360(dtype)
#       114    0.000    0.000    0.000    0.000 datetimes.py:364(tz)
#        24    0.000    0.000    0.003    0.000 datetimes.py:365(_from_sequence)
#        24    0.000    0.000   63.589    2.650 datetimes.py:401(to_datetime)
#         1    0.000    0.000    0.005    0.005 datetimes.py:503(union_many)
#      1671    0.000    0.000    0.000    0.000 datetimes.py:515(dtype)
#        23    0.000    0.000    0.000    0.000 datetimes.py:533(_can_fast_union)
#       402    0.000    0.000    0.000    0.000 datetimes.py:538(tz)
#        83    0.000    0.000    0.000    0.000 datetimes.py:54(tz_to_dtype)
#        11    0.000    0.000    0.000    0.000 datetimes.py:593(_wrap_setop_result)
#        23    0.000    0.000    0.000    0.000 datetimes.py:785(_maybe_utc_convert)
#        11    0.000    0.000    0.000    0.000 datetimes.py:919(_maybe_promote)
#       203    0.000    0.000    0.001    0.000 dtypes.py:120(__str__)
#       299    0.000    0.000    0.002    0.000 dtypes.py:452(construct_from_string)
#       131    0.000    0.000    0.000    0.000 dtypes.py:596(__init__)
#       363    0.000    0.000    0.000    0.000 dtypes.py:650(unit)
#       837    0.000    0.000    0.000    0.000 dtypes.py:655(tz)
#       120    0.000    0.000    0.000    0.000 dtypes.py:672(construct_from_string)
#      2514    0.002    0.000    0.003    0.000 dtypes.py:68(find)
#       203    0.000    0.000    0.001    0.000 dtypes.py:703(__unicode__)
#       203    0.000    0.000    0.001    0.000 dtypes.py:706(name)
#       307    0.000    0.000    0.002    0.000 dtypes.py:716(__eq__)
#       176    0.000    0.000    0.001    0.000 dtypes.py:786(construct_from_string)
#       917    0.001    0.000    0.005    0.000 dtypes.py:827(is_dtype)
#        96    0.000    0.000    0.000    0.000 dtypes.py:929(construct_from_string)
#       757    0.001    0.000    0.004    0.000 dtypes.py:973(is_dtype)
#        72    0.000    0.000    0.005    0.000 frame.py:2893(__getitem__)
#        48    0.000    0.000    0.001    0.000 frame.py:3342(_box_item_values)
#        48    0.000    0.000    0.001    0.000 frame.py:3349(_box_col_values)
#        24    0.000    0.000    0.010    0.000 frame.py:3356(__setitem__)
#        24    0.000    0.000    0.000    0.000 frame.py:3416(_ensure_valid_index)
#        24    0.000    0.000    0.010    0.000 frame.py:3433(_set_item)
#        24    0.000    0.000    0.002    0.000 frame.py:3565(_sanitize_column)
#        24    0.000    0.000    0.001    0.000 frame.py:3585(reindexer)
#        25    0.000    0.000    0.083    0.003 frame.py:378(__init__)
#        24    0.000    0.000    0.030    0.001 frame.py:3942(rename)
#        24    0.000    0.000    0.016    0.001 frame.py:4049(set_index)
#        24    0.000    0.000    0.000    0.000 frame.py:491(shape)
#        24    0.000    0.000    0.000    0.000 frame.py:937(__len__)
#        24    0.000    0.000    0.000    0.000 frequencies.py:59(to_offset)
#        48    0.000    0.000    0.000    0.000 fromnumeric.py:2847(ndim)
#        24    0.000    0.000    0.000    0.000 function.py:40(__call__)
#        24    0.000    0.000    0.003    0.000 generic.py:11018(logical_func)
#       217    0.001    0.000    0.001    0.000 generic.py:127(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:144(_init_mgr)
#        48    0.000    0.000    0.000    0.000 generic.py:178(_validate_dtype)
#        48    0.000    0.000    0.000    0.000 generic.py:297(_construct_axes_from_arguments)
#        72    0.000    0.000    0.004    0.000 generic.py:3056(_get_item_cache)
#        48    0.000    0.000    0.000    0.000 generic.py:3070(_set_as_cached)
#        24    0.000    0.000    0.000    0.000 generic.py:3115(_maybe_update_cacher)
#       120    0.000    0.000    0.000    0.000 generic.py:3149(_clear_item_cache)
#        24    0.000    0.000    0.008    0.000 generic.py:3171(_set_item)
#        48    0.000    0.000    0.000    0.000 generic.py:3205(_check_setitem_copy)
#        24    0.000    0.000    0.007    0.000 generic.py:3289(__delitem__)
#        48    0.000    0.000    0.000    0.000 generic.py:334(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:337(_from_axes)
#        50    0.000    0.000    0.000    0.000 generic.py:349(_get_axis_number)
#        96    0.000    0.000    0.000    0.000 generic.py:363(_get_axis_name)
#        48    0.000    0.000    0.000    0.000 generic.py:377(_get_axis)
#        25    0.000    0.000    0.000    0.000 generic.py:381(_get_block_manager_axis)
#        24    0.000    0.000    0.000    0.000 generic.py:3840(_update_inplace)
#        24    0.000    0.000    0.002    0.000 generic.py:4113(reindex)
#        72    0.000    0.000    0.000    0.000 generic.py:426(_info_axis)
#        48    0.000    0.000    0.001    0.000 generic.py:4341(<genexpr>)
#        26    0.000    0.000    0.000    0.000 generic.py:450(ndim)
#        25    0.000    0.000    0.000    0.000 generic.py:5036(__finalize__)
#   290/266    0.001    0.000    0.004    0.000 generic.py:5053(__getattr__)
#       480    0.002    0.000    0.023    0.000 generic.py:5069(__setattr__)
#        72    0.000    0.000    0.001    0.000 generic.py:5122(_protect_consolidate)
#        72    0.000    0.000    0.001    0.000 generic.py:5132(_consolidate_inplace)
#        72    0.000    0.000    0.001    0.000 generic.py:5135(f)
#        24    0.000    0.000    0.000    0.000 generic.py:5140(_consolidate)
#        48    0.000    0.000    0.009    0.000 generic.py:637(_set_axis)
#     21663    0.006    0.000    0.015    0.000 generic.py:7(_check)
#        24    0.000    0.000    0.004    0.000 generic.py:7083(isnull)
#        24    0.000    0.000    0.030    0.001 generic.py:960(rename)
#        24    0.000    0.000    0.001    0.000 index_tricks.py:316(__getitem__)
#        24    0.000    0.000    0.000    0.000 indexing.py:2450(convert_to_index_sliceable)
#       192    0.000    0.000    0.000    0.000 inference.py:121(is_iterator)
#        24    0.000    0.000    0.000    0.000 inference.py:160(is_file_like)
#       487    0.001    0.000    0.002    0.000 inference.py:253(is_list_like)
#        96    0.000    0.000    0.000    0.000 inference.py:438(is_hashable)
#   1244212    0.946    0.000    1.365    0.000 locale.py:379(normalize)
#   1244212    0.548    0.000    1.913    0.000 locale.py:462(_parse_localename)
#   1244212    0.680    0.000    2.977    0.000 locale.py:565(getlocale)
#        59    0.000    0.000    0.000    0.000 managers.py:1014(<genexpr>)
#        24    0.002    0.000    0.008    0.000 managers.py:1019(set)
#        59    0.000    0.000    0.000    0.000 managers.py:1098(<genexpr>)
#        48    0.000    0.000    0.002    0.000 managers.py:1110(<genexpr>)
#       219    0.000    0.000    0.001    0.000 managers.py:139(shape)
#       657    0.000    0.000    0.001    0.000 managers.py:141(<genexpr>)
#       229    0.000    0.000    0.000    0.000 managers.py:143(ndim)
#       144    0.000    0.000    0.006    0.000 managers.py:1443(__init__)
#        72    0.000    0.000    0.009    0.000 managers.py:147(set_axis)
#       264    0.000    0.000    0.000    0.000 managers.py:1488(_block)
#        24    0.000    0.000    0.000    0.000 managers.py:1522(dtype)
#        24    0.000    0.000    0.000    0.000 managers.py:1546(external_values)
#       216    0.000    0.000    0.000    0.000 managers.py:1549(internal_values)
#        24    0.000    0.000    0.000    0.000 managers.py:1572(is_consolidated)
#        24    0.000    0.000    0.027    0.001 managers.py:159(rename_axis)
#        24    0.000    0.000    0.031    0.001 managers.py:1663(create_block_manager_from_arrays)
#        24    0.001    0.000    0.028    0.001 managers.py:1696(form_blocks)
#        24    0.000    0.000    0.000    0.000 managers.py:174(_is_single_block)
#        24    0.000    0.000    0.007    0.000 managers.py:1796(_simple_blockify)
#        35    0.000    0.000    0.010    0.000 managers.py:1810(_multi_blockify)
#       285    0.000    0.000    0.000    0.000 managers.py:1814(<lambda>)
#        59    0.012    0.000    0.013    0.000 managers.py:1841(_stack_arrays)
#       309    0.000    0.000    0.001    0.000 managers.py:1844(_asarray_compat)
#        59    0.000    0.000    0.000    0.000 managers.py:1850(_shape_compat)
#        73    0.001    0.000    0.004    0.000 managers.py:186(_rebuild_blknos_and_blklocs)
#        24    0.000    0.000    0.006    0.000 managers.py:1988(_transform_index)
#        24    0.000    0.000    0.000    0.000 managers.py:2004(<listcomp>)
#        24    0.000    0.000    0.001    0.000 managers.py:2008(_fast_count_smallints)
#         1    0.000    0.000    0.022    0.022 managers.py:2029(concatenate_block_managers)
#         1    0.000    0.000    0.000    0.000 managers.py:2041(<listcomp>)
#       230    0.000    0.000    0.000    0.000 managers.py:206(items)
#        13    0.000    0.000    0.000    0.000 managers.py:291(__len__)
#        25    0.000    0.000    0.001    0.000 managers.py:306(_verify_integrity)
#       121    0.000    0.000    0.000    0.000 managers.py:308(<genexpr>)
#        24    0.000    0.000    0.019    0.001 managers.py:318(apply)
#        24    0.000    0.000    0.000    0.000 managers.py:376(<dictcomp>)
#       120    0.000    0.000    0.000    0.000 managers.py:591(is_consolidated)
#        73    0.000    0.000    0.003    0.000 managers.py:599(_consolidate_check)
#        73    0.000    0.000    0.003    0.000 managers.py:600(<listcomp>)
#       107    0.000    0.000    0.000    0.000 managers.py:706(nblocks)
#        24    0.000    0.000    0.020    0.001 managers.py:710(copy)
#        48    0.000    0.000    0.001    0.000 managers.py:729(<lambda>)
#        24    0.000    0.000    0.001    0.000 managers.py:730(<listcomp>)
#        72    0.000    0.000    0.000    0.000 managers.py:911(consolidate)
#        72    0.000    0.000    0.000    0.000 managers.py:927(_consolidate_inplace)
#        48    0.000    0.000    0.002    0.000 managers.py:934(get)
#        48    0.000    0.000    0.002    0.000 managers.py:963(iget)
#        49    0.000    0.000    0.006    0.000 managers.py:97(__init__)
#        49    0.000    0.000    0.000    0.000 managers.py:98(<listcomp>)
#        24    0.001    0.000    0.006    0.000 managers.py:981(delete)
#       108    0.000    0.000    0.006    0.000 missing.py:105(_isna_new)
#        60    0.001    0.000    0.005    0.000 missing.py:183(_isna_ndarraylike)
#       108    0.000    0.000    0.006    0.000 missing.py:25(isna)
#        48    0.000    0.000    0.001    0.000 missing.py:360(array_equivalent)
#        35    0.000    0.000    0.000    0.000 missing.py:530(clean_reindex_fill_method)
#        35    0.000    0.000    0.000    0.000 missing.py:71(clean_fill_method)
#        24    0.000    0.000    0.000    0.000 nanops.py:180(_get_fill_value)
#        24    0.000    0.000    0.002    0.000 nanops.py:203(_get_values)
#        24    0.000    0.000    0.000    0.000 nanops.py:270(_na_ok_dtype)
#        24    0.000    0.000    0.002    0.000 nanops.py:337(nanany)
#        72    0.000    0.000    0.000    0.000 numeric.py:113(is_all_dates)
#        58    0.000    0.000    0.001    0.000 numeric.py:2551(array_equal)
#        48    0.000    0.000    0.000    0.000 numeric.py:2656(seterr)
#        48    0.000    0.000    0.000    0.000 numeric.py:2758(geterr)
#        24    0.000    0.000    0.000    0.000 numeric.py:3054(__init__)
#        24    0.000    0.000    0.000    0.000 numeric.py:3058(__enter__)
#        24    0.000    0.000    0.000    0.000 numeric.py:3063(__exit__)
#       885    0.000    0.000    0.002    0.000 numeric.py:469(asarray)
#        11    0.000    0.000    0.000    0.000 numeric.py:67(_shallow_copy)
#        94    0.000    0.000    0.001    0.000 numeric.py:676(require)
#        94    0.000    0.000    0.000    0.000 numeric.py:748(<setcomp>)
#      1784    0.002    0.000    0.003    0.000 numerictypes.py:293(issubclass_)
#       892    0.001    0.000    0.004    0.000 numerictypes.py:365(issubdtype)
#        96    0.000    0.000    0.000    0.000 numerictypes.py:578(_can_coerce_all)
#       192    0.000    0.000    0.000    0.000 numerictypes.py:587(<listcomp>)
#        48    0.000    0.000    0.001    0.000 numerictypes.py:602(find_common_type)
#        48    0.000    0.000    0.000    0.000 numerictypes.py:654(<listcomp>)
#        48    0.000    0.000    0.000    0.000 numerictypes.py:655(<listcomp>)
#        23    0.000    0.000    0.000    0.000 ops.py:43(get_op_result_name)
#        23    0.000    0.000    0.000    0.000 ops.py:66(_maybe_match_name)
#       144    0.000    0.000    0.000    0.000 parse.py:109(_coerce_args)
#        72    0.000    0.000    0.001    0.000 parse.py:361(urlparse)
#        72    0.000    0.000    0.000    0.000 parse.py:394(urlsplit)
#         1    0.000    0.000    0.000    0.000 parse.py:83(clear_cache)
#       144    0.000    0.000    0.000    0.000 parse.py:98(_noop)
#        24    0.000    0.000    0.021    0.001 parsers.py:1120(_make_engine)
#        24    0.000    0.000    0.679    0.028 parsers.py:1137(read)
#        24    0.000    0.000    0.000    0.000 parsers.py:1162(_create_index)
#        72    0.000    0.000    0.000    0.000 parsers.py:1176(_is_index_col)
#        72    0.000    0.000    0.000    0.000 parsers.py:1180(_is_potential_multi_index)
#       144    0.000    0.000    0.000    0.000 parsers.py:1195(<genexpr>)
#        24    0.000    0.000    0.000    0.000 parsers.py:1274(_validate_usecols_arg)
#        24    0.000    0.000    0.000    0.000 parsers.py:1329(_validate_parse_dates_arg)
#        24    0.000    0.000    0.000    0.000 parsers.py:1352(__init__)
#        24    0.000    0.000    0.000    0.000 parsers.py:1423(_has_complex_date_col)
#        24    0.000    0.000    0.000    0.000 parsers.py:1502(_maybe_dedup_names)
#        48    0.000    0.000    0.000    0.000 parsers.py:1530(_maybe_make_multi_index_columns)
#        24    0.000    0.000    0.000    0.000 parsers.py:1536(_make_index)
#        24    0.000    0.000    0.000    0.000 parsers.py:1814(_do_date_conversions)
#        24    0.020    0.001    0.020    0.001 parsers.py:1830(__init__)
#        24    0.000    0.000    0.001    0.000 parsers.py:1926(close)
#        24    0.000    0.000    0.000    0.000 parsers.py:1936(_set_noconvert_columns)
#        24    0.000    0.000    0.595    0.025 parsers.py:1993(read)
#        24    0.000    0.000    0.000    0.000 parsers.py:2064(<listcomp>)
#        24    0.000    0.000    0.000    0.000 parsers.py:2066(<dictcomp>)
#        24    0.000    0.000    0.000    0.000 parsers.py:3157(_make_date_converter)
#        24    0.000    0.000    0.000    0.000 parsers.py:3195(_process_date_conversion)
#        24    0.000    0.000    0.000    0.000 parsers.py:3278(_clean_na_values)
#        48    0.000    0.000    0.000    0.000 parsers.py:347(_validate_integer)
#        24    0.000    0.000    0.000    0.000 parsers.py:377(_validate_names)
#        24    0.002    0.000    0.719    0.030 parsers.py:403(_read)
#        24    0.000    0.000    0.720    0.030 parsers.py:536(parser_f)
#        24    0.000    0.000    0.022    0.001 parsers.py:813(__init__)
#        24    0.000    0.000    0.001    0.000 parsers.py:897(close)
#        24    0.000    0.000    0.001    0.000 parsers.py:900(_get_options_with_defaults)
#        24    0.000    0.000    0.000    0.000 parsers.py:939(_check_file_or_buffer)
#        24    0.000    0.000    0.000    0.000 parsers.py:956(_clean_options)
#        24    0.000    0.000    0.000    0.000 posixpath.py:144(basename)
#        72    0.000    0.000    0.000    0.000 posixpath.py:232(expanduser)
#        24    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#        48    0.000    0.000    0.000    0.000 range.py:136(_simple_new)
#        24    0.000    0.000    0.000    0.000 range.py:165(_validate_dtype)
#        24    0.000    0.000    0.000    0.000 range.py:184(_get_data_as_items)
#        24    0.000    0.000    0.000    0.000 range.py:272(_shallow_copy)
#        24    0.000    0.000    0.000    0.000 range.py:330(equals)
#       669    0.001    0.000    0.001    0.000 range.py:510(__len__)
#        24    0.000    0.000    0.001    0.000 range.py:69(__new__)
#        48    0.000    0.000    0.000    0.000 range.py:89(ensure_int)
#   192/144    0.002    0.000    0.040    0.000 series.py:152(__init__)
#        48    0.000    0.000    0.021    0.000 series.py:271(_init_dict)
#       192    0.000    0.000    0.001    0.000 series.py:354(_set_axis)
#        24    0.000    0.000    0.003    0.000 series.py:3600(_reduce)
#        24    0.000    0.000    0.002    0.000 series.py:3735(reindex)
#       192    0.000    0.000    0.000    0.000 series.py:382(_set_subtyp)
#       264    0.000    0.000    0.001    0.000 series.py:392(name)
#       216    0.000    0.000    0.000    0.000 series.py:399(name)
#        24    0.000    0.000    0.000    0.000 series.py:406(dtype)
#        24    0.000    0.000    0.004    0.000 series.py:4209(isnull)
#        24    0.000    0.000    0.000    0.000 series.py:434(values)
#       216    0.000    0.000    0.001    0.000 series.py:476(_values)
#       120    0.000    0.000    0.000    0.000 six.py:184(find_module)
#    311053    0.056    0.000    0.056    0.000 tz.py:74(utcoffset)
#       551    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10da55dd8}
#      1248    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        48    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#       120    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#      1248    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#   1244212    0.384    0.000    0.384    0.000 {built-in method _locale.setlocale}
#       768    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       768    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#   264/120    0.000    0.000    0.023    0.000 {built-in method builtins.__import__}
# 622348/622324    0.340    0.000    0.794    0.000 {built-in method builtins.all}
#    311173    0.039    0.000    0.039    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   64.428   64.428 {built-in method builtins.exec}
# 6253275/6253240    1.087    0.000    1.088    0.000 {built-in method builtins.getattr}
#    938538    0.226    0.000    0.226    0.000 {built-in method builtins.hasattr}
#       264    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#   2839639    0.370    0.000    0.386    0.000 {built-in method builtins.isinstance}
#     11924    0.003    0.000    0.003    0.000 {built-in method builtins.issubclass}
#       337    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 8093904/8092870    1.028    0.000    3.405    0.000 {built-in method builtins.len}
#       681    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#   3732636    0.554    0.000    0.554    0.000 {built-in method builtins.setattr}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#    311126    0.615    0.000    2.119    0.000 {built-in method builtins.sum}
#       262    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#      1211    0.002    0.000    0.002    0.000 {built-in method numpy.array}
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.bincount}
#        49    0.000    0.000    0.000    0.000 {built-in method numpy.concatenate}
#       449    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
#        96    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        24    0.000    0.000    0.000    0.000 {built-in method numpy.putmask}
#        48    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        48    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        48    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        48    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        24    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#        24    4.454    0.186   63.571    2.649 {built-in method pandas._libs.tslib.array_to_datetime}
#       131    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#        47    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.tz_compare}
#        96    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        48    0.002    0.000    0.002    0.000 {built-in method posix.getcwd}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#       360    0.005    0.000    0.005    0.000 {built-in method posix.stat}
#        24    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#        72    0.000    0.000    0.001    0.000 {method 'add' of 'pandas._libs.internals.BlockPlacement' objects}
#        72    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        37    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       133    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#   3422668    0.621    0.000    0.621    0.000 {method 'append' of 'list' objects}
#        24    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       122    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        24    0.000    0.000    0.000    0.000 {method 'clear_mapping' of 'pandas._libs.index.IndexEngine' objects}
#        24    0.001    0.000    0.001    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#        72    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       212    0.028    0.000    0.028    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        24    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#    622106    0.080    0.000    0.080    0.000 {method 'end' of '_sre.SRE_Match' objects}
#        96    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        83    0.000    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#       170    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       990    0.002    0.000    0.004    0.000 {method 'format' of 'str' objects}
#   3113296    0.552    0.000    0.552    0.000 {method 'get' of 'dict' objects}
#        11    0.009    0.001    0.010    0.001 {method 'get_indexer' of 'pandas._libs.index.DatetimeEngine' objects}
#       144    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    933159    0.102    0.000    0.102    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#   4665795    0.439    0.000    0.439    0.000 {method 'isalpha' of 'str' objects}
#   9331590    0.802    0.000    0.802    0.000 {method 'isdigit' of 'str' objects}
#   1866318    0.182    0.000    0.182    0.000 {method 'isspace' of 'str' objects}
#       458    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      1800    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#   6532123    0.740    0.000    0.740    0.000 {method 'lower' of 'str' objects}
#   1244212    0.856    0.000    0.856    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        83    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       644    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#   1866342    0.532    0.000    0.532    0.000 {method 'pop' of 'list' objects}
#       132    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#   7465272    0.902    0.000    0.902    0.000 {method 'read' of '_io.StringIO' objects}
#        24    0.580    0.024    0.594    0.025 {method 'read' of 'pandas._libs.parsers.TextReader' objects}
#       205    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    622106    1.349    0.000    1.349    0.000 {method 'replace' of 'datetime.datetime' objects}
#        24    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1081    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#      3600    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#       122    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       108    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        94    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       533    0.001    0.000    0.001    0.000 {method 'view' of 'numpy.ndarray' objects}
#        52    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#       192    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        11    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        14    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis0_float64_float64}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_int64_float64}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int64_float64}
#        35    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#        48    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#        96    0.002    0.000    0.016    0.000 {pandas._libs.lib.clean_index_list}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_datetimelike_array}
#       169    0.005    0.000    0.006    0.000 {pandas._libs.lib.infer_dtype}
#        72    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       409    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       122    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       681    0.001    0.000    0.002    0.000 {pandas._libs.lib.is_scalar}
#       144    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#        24    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.timezones.tz_standardize}

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    #df.timestamp = pd.to_datetime(df.timestamp) #hold off for now...
    df.set_index('timestamp', inplace=True)
    prefix = os.path.basename(filename).replace('.csv','')
    df.columns = [ "{}:{}".format(prefix, x) for x in df.columns ] 
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=1, sort=False)
    df.index = pd.to_datetime(df.index)
    return df
# Out:
# Overwriting utils.py

# %%
# %load_ext autoreload
# %reload_ext autoreload

# %%
# %autoreload 2
import utils

df = utils.read_dir(filenames)
df.shape
# Out:
# (12961, 260)

# %%
df.head()
# Out:
#                            triplex_meter:monthly_bill:triplex_meter_0  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0012
# 2013-07-01 00:04:00+00:00                                     10.0018
#
#                            triplex_meter:monthly_bill:triplex_meter_1  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0012
# 2013-07-01 00:04:00+00:00                                     10.0018
#
#                            triplex_meter:monthly_bill:triplex_meter_2  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0012
# 2013-07-01 00:04:00+00:00                                     10.0018
#
#                            triplex_meter:monthly_bill:triplex_meter_3  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0013
# 2013-07-01 00:04:00+00:00                                     10.0019
#
#                            triplex_meter:monthly_bill:triplex_meter_4  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0012
# 2013-07-01 00:04:00+00:00                                     10.0018
#
#                            triplex_meter:monthly_bill:triplex_meter_5  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0012
# 2013-07-01 00:04:00+00:00                                     10.0018
#
#                            triplex_meter:monthly_bill:triplex_meter_6  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0013
# 2013-07-01 00:04:00+00:00                                     10.0019
#
#                            triplex_meter:monthly_bill:triplex_meter_7  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0006
# 2013-07-01 00:03:00+00:00                                     10.0013
# 2013-07-01 00:04:00+00:00                                     10.0019
#
#                            triplex_meter:monthly_bill:triplex_meter_8  \
# timestamp
# 2013-07-01 00:00:00+00:00                                      0.0000
# 2013-07-01 00:01:00+00:00                                     10.0000
# 2013-07-01 00:02:00+00:00                                     10.0007
# 2013-07-01 00:03:00+00:00                                     10.0013
# 2013-07-01 00:04:00+00:00                                     10.0020
#
#                            triplex_meter:monthly_bill:triplex_meter_9  ...  \
# timestamp                                                              ...
# 2013-07-01 00:00:00+00:00                                      0.0000  ...
# 2013-07-01 00:01:00+00:00                                     10.0000  ...
# 2013-07-01 00:02:00+00:00                                     10.0007  ...
# 2013-07-01 00:03:00+00:00                                     10.0013  ...
# 2013-07-01 00:04:00+00:00                                     10.0020  ...
#
#                            triplex_meter:monthly_energy:triplex_meter_10  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.006402
# 2013-07-01 00:02:00+00:00                                       0.006402
# 2013-07-01 00:03:00+00:00                                       0.012805
# 2013-07-01 00:04:00+00:00                                       0.019207
#
#                            triplex_meter:monthly_energy:triplex_meter_11  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.006402
# 2013-07-01 00:02:00+00:00                                       0.006402
# 2013-07-01 00:03:00+00:00                                       0.012805
# 2013-07-01 00:04:00+00:00                                       0.019207
#
#                            triplex_meter:monthly_energy:triplex_meter_12  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.006402
# 2013-07-01 00:02:00+00:00                                       0.006402
# 2013-07-01 00:03:00+00:00                                       0.012805
# 2013-07-01 00:04:00+00:00                                       0.019207
#
#                            triplex_meter:monthly_energy:triplex_meter_13  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.008858
# 2013-07-01 00:02:00+00:00                                       0.008858
# 2013-07-01 00:03:00+00:00                                       0.017716
# 2013-07-01 00:04:00+00:00                                       0.026575
#
#                            triplex_meter:monthly_energy:triplex_meter_14  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.008858
# 2013-07-01 00:02:00+00:00                                       0.008858
# 2013-07-01 00:03:00+00:00                                       0.017716
# 2013-07-01 00:04:00+00:00                                       0.026575
#
#                            triplex_meter:monthly_energy:triplex_meter_15  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.008858
# 2013-07-01 00:02:00+00:00                                       0.008858
# 2013-07-01 00:03:00+00:00                                       0.017716
# 2013-07-01 00:04:00+00:00                                       0.026575
#
#                            triplex_meter:monthly_energy:triplex_meter_16  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.008847
# 2013-07-01 00:02:00+00:00                                       0.008847
# 2013-07-01 00:03:00+00:00                                       0.017695
# 2013-07-01 00:04:00+00:00                                       0.026542
#
#                            triplex_meter:monthly_energy:triplex_meter_17  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.008847
# 2013-07-01 00:02:00+00:00                                       0.008847
# 2013-07-01 00:03:00+00:00                                       0.017695
# 2013-07-01 00:04:00+00:00                                       0.026542
#
#                            triplex_meter:monthly_energy:triplex_meter_18  \
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.004519
# 2013-07-01 00:02:00+00:00                                       0.004519
# 2013-07-01 00:03:00+00:00                                       0.009037
# 2013-07-01 00:04:00+00:00                                       0.013556
#
#                            triplex_meter:monthly_energy:triplex_meter_19
# timestamp
# 2013-07-01 00:00:00+00:00                                       0.000000
# 2013-07-01 00:01:00+00:00                                       0.006395
# 2013-07-01 00:02:00+00:00                                       0.006395
# 2013-07-01 00:03:00+00:00                                       0.012789
# 2013-07-01 00:04:00+00:00                                       0.019184
#
# [5 rows x 260 columns]

# %% [markdown]
# ## The stacked method

# %%
filename = 'data/measured_real_power.csv'

df = pd.read_csv(filename, skiprows=8)
df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
df = df.melt(id_vars='timestamp')
df.head()
# Out:
#                  timestamp         variable    value
# 0  2013-07-01 00:00:00 UTC  triplex_meter_0  510.912
# 1  2013-07-01 00:01:00 UTC  triplex_meter_0  510.912
# 2  2013-07-01 00:02:00 UTC  triplex_meter_0  510.912
# 3  2013-07-01 00:03:00 UTC  triplex_meter_0  510.912
# 4  2013-07-01 00:04:00 UTC  triplex_meter_0  510.911

# %%
prefix = os.path.basename(filename).replace('.csv','')
df['attribute'] = prefix
df.head()
# Out:
#                  timestamp         variable    value            attribute
# 0  2013-07-01 00:00:00 UTC  triplex_meter_0  510.912  measured_real_power
# 1  2013-07-01 00:01:00 UTC  triplex_meter_0  510.912  measured_real_power
# 2  2013-07-01 00:02:00 UTC  triplex_meter_0  510.912  measured_real_power
# 3  2013-07-01 00:03:00 UTC  triplex_meter_0  510.912  measured_real_power
# 4  2013-07-01 00:04:00 UTC  triplex_meter_0  510.911  measured_real_power

# %% [markdown]
# We can stack this with concat

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df = df.melt(id_vars='timestamp')
    prefix = os.path.basename(filename).replace('.csv','')
    df['attribute'] = prefix
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=0, sort=False)  # axis = 0 for stacking
    #df.index = pd.to_datetime(df.index)
    return df
# Out:
# Overwriting utils.py

# %%
# %autoreload 2
import utils

df = utils.read_dir(filenames)
df.shape
# Out:
# (3369860, 4)

# %%
# takes a really long time....
#df.timestamp = pd.to_datetime(df.timestamp)

# %% [markdown]
# Reshaping can help...

# %%
tmp = df.pivot_table(index='timestamp', columns=['variable', 'attribute'], values='value')
print(tmp.shape)
df.index = pd.to_datetime(df.index)
final = tmp.reset_index().melt(id_vars='timestamp')
final.shape
# Out:
# (12961, 260)
# (3369860, 4)

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df = df.melt(id_vars='timestamp')
    prefix = os.path.basename(filename).replace('.csv','')
    df['attribute'] = prefix
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=0, sort=False)  # axis = 0 for stacking
    #df.index = pd.to_datetime(df.index)
    tmp = df.pivot_table(index='timestamp', columns=['variable', 'attribute'], values='value')
    tmp.index = pd.to_datetime(tmp.index)
    final = tmp.reset_index().melt(id_vars='timestamp')
    return final
# Out:
# Overwriting utils.py
